# %% [markdown]
# # Encuesta de Simulación

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as pp

from pprint import pprint

# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('preguntas.csv')

# %%
norm_d = {
    column[:2]: round(data[column].value_counts(normalize=True)*100, 2)
    for column in data.columns
}

# %%
dat_t = pd.DataFrame(norm_d).transpose()

# %%
f = pp.figure(figsize=(15,8))
pp.title('Encuesta de simulación', color='black')
colorcitos = [
    "seagreen", # Muy de acuerdo
    "limegreen", # De acuerdo
    "salmon", # Neutral
    "orangered", # Desacuerdo
    "crimson"#"Muy en desacuerdo
]

dat_t = dat_t.reindex_axis([
        "Muy de acuerdo",
        "De acuerdo",
        "Neutral",
        "Desacuerdo",
        "Muy en desacuerdo"
    ], 
    axis = 1
)

ax = dat_t.plot(
    kind="barh",
    stacked=True,
    ax=f.gca(),
    color=colorcitos,
    grid=True,
)

ax.set_xlabel("Porcentajes de resultado")
ax.set_ylabel("No. de Pregunta")
ax.legend(loc='center left',bbox_to_anchor=(1.0, .5))
ax.invert_yaxis()

# %% [markdown]
# ## Preguntas enumeradas

# %%
pprint(list(data.columns))
# Out:
# ['1.La simulación es un método docente útil para el aprendizaje',
#  '2.Los escenarios donde se desarrolla la simulación son realistas.',
#  '3.La experiencia con simulación ha mejorado mis habilidades técnicas.',
#  '4.La simulación ayuda a desarrollar el razonamiento crítico y la toma de '
#  'decisiones.',
#  '5.Los casos simulados se adaptan a mis conocimientos teóricos.',
#  '6.La experiencia con el simulador ha aumentado mi seguridad y confianza.',
#  '7.La simulación me ha ayudado a integrar teoría y práctica',
#  '8.Los talleres con el simulador me han motivado a aprender.',
#  '9.En simulación, es útil el ver las propias actuaciones grabadas.',
#  '10.  La duración del caso es adecuada.',
#  '11.  La capacitación del profesorado es adecuada.',
#  '12.  La simulación fomenta la comunicación entre los miembros del equipo.',
#  '13.  La simulación clínica ayuda a priorizar la resolución de problemas '
#  'clínicos.',
# ...

# %% [markdown]
# ## Porcentaje de respuestas en preguntas

# %%
dat_t[dat_t.columns[:]].fillna(0).astype(str)+" %"
# Out:
#    Muy de acuerdo De acuerdo  Neutral Desacuerdo Muy en desacuerdo
# 1.        82.35 %    11.76 %   2.94 %      0.0 %            2.94 %
# 2.        32.35 %    41.18 %  20.59 %     5.88 %             0.0 %
# 3.        58.82 %    32.35 %   2.94 %     2.94 %            2.94 %
# 4.        64.71 %    29.41 %   2.94 %      0.0 %            2.94 %
# 5.        55.88 %    32.35 %   8.82 %      0.0 %            2.94 %
# 6.        52.94 %    26.47 %  14.71 %     2.94 %            2.94 %
# 7.        64.71 %    29.41 %   2.94 %      0.0 %            2.94 %
# 8.        61.76 %    32.35 %    0.0 %     2.94 %            2.94 %
# 9.        23.53 %    23.53 %  38.24 %     2.94 %           11.76 %
# 10        14.71 %    47.06 %  26.47 %     8.82 %            2.94 %
# 11        55.88 %    35.29 %   5.88 %      0.0 %            2.94 %
# 12        55.88 %    29.41 %   8.82 %     5.88 %             0.0 %
# 13        70.59 %    20.59 %   2.94 %     5.88 %             0.0 %
# ...

# %% [markdown]
# ## Resultados de la encuesta

# %%
data
# Out:
#    1.La simulación es un método docente útil para el aprendizaje  \
# 0                                      Muy de acuerdo
# 1                                      Muy de acuerdo
# 2                                      Muy de acuerdo
# 3                                      Muy de acuerdo
# 4                                      Muy de acuerdo
# 5                                          De acuerdo
# 6                                      Muy de acuerdo
# 7                                      Muy de acuerdo
# 8                                      Muy de acuerdo
# 9                                      Muy de acuerdo
# 10                                     Muy de acuerdo
# 11                                         De acuerdo
# 12                                     Muy de acuerdo
# 13                                     Muy de acuerdo
# 14                                     Muy de acuerdo
# 15                                     Muy de acuerdo
# ...
